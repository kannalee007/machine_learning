# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = 2 * np.random.rand(100,1)
x
# Out:
# array([[1.18878939],
#        [1.96099738],
#        [0.66839198],
#        [1.21386085],
#        [1.72836568],
#        [0.06329984],
#        [1.1125735 ],
#        [1.39634695],
#        [0.82668894],
#        [1.38167996],
#        [1.31191636],
#        [0.24279107],
#        [1.62432911],
#        [1.5361099 ],
#        [0.38859573],
#        [0.99767938],
#        [0.25471912],
#        [0.03094778],
#        [0.02556884],
#        [1.78837636],
#        [1.55711577],
#        [1.79805824],
#        [0.69613028],
#        [0.63148179],
#        [0.87975827],
#        [0.92407284],
#        [0.22496953],
#        [1.95333624],
#        [1.89316455],
#        [1.6993922 ],
#        [1.68420379],
#        [1.00237783],
#        [1.1532231 ],
#        [0.6748759 ],
#        [0.67393535],
#        [1.29039882],
#        [1.76569631],
#        [0.80827121],
#        [1.07470677],
#        [0.74587181],
#        [0.0071132 ],
#        [1.60036418],
#        [0.75972437],
# ...

# %%
y = 3*x + 2 #in the form of y = mx+c (linear data) 
y
# Out:
# array([[5.56636818],
#        [7.88299213],
#        [4.00517595],
#        [5.64158256],
#        [7.18509704],
#        [2.18989952],
#        [5.3377205 ],
#        [6.18904085],
#        [4.48006681],
#        [6.14503988],
#        [5.93574907],
#        [2.7283732 ],
#        [6.87298733],
#        [6.60832969],
#        [3.16578719],
#        [4.99303813],
#        [2.76415737],
#        [2.09284335],
#        [2.07670652],
#        [7.36512909],
#        [6.67134732],
#        [7.39417471],
#        [4.08839083],
#        [3.89444537],
#        [4.63927482],
#        [4.77221853],
#        [2.6749086 ],
#        [7.86000871],
#        [7.67949366],
#        [7.09817661],
#        [7.05261136],
#        [5.00713348],
#        [5.45966931],
#        [4.02462771],
#        [4.02180604],
#        [5.87119646],
#        [7.29708894],
#        [4.42481363],
#        [5.22412032],
#        [4.23761543],
#        [2.02133959],
#        [6.80109255],
#        [4.27917311],
# ...

# %%
plt.plot(x,y, "b.")
plt.xlabel("$x_1$", fontsize = 13)
plt.ylabel("$y$", rotation = 0, fontsize = 13)
plt.axis([0,2,0,15])
plt.show()

# %%
#as we seen in the above graph it ia a perfect linear data as we made our own (but genreally perfect lnear data does not exsist in real problems

# %%
y = 3*x + np.random.randn(100,1) #in the form of y = mx+c (linear data) 
y
# Out:
# array([[ 4.61945278],
#        [ 5.38260861],
#        [ 0.48528854],
#        [ 5.18688534],
#        [ 3.87612439],
#        [-0.78132318],
#        [ 3.9827351 ],
#        [ 3.20023485],
#        [ 2.91129114],
#        [ 3.84986506],
#        [ 4.80390286],
#        [-0.34007121],
#        [ 4.24959337],
#        [ 6.20527079],
#        [ 0.34892523],
#        [ 3.57498703],
#        [ 1.49803316],
#        [-0.63116806],
#        [ 2.79335122],
#        [ 3.96854771],
#        [ 5.27060032],
#        [ 5.17081457],
#        [ 2.54576056],
#        [ 0.06198961],
#        [ 4.31042668],
#        [ 3.60919323],
#        [ 1.72567818],
#        [ 5.37538906],
#        [ 4.75745957],
#        [ 5.93421201],
#        [ 6.22731242],
#        [ 2.52735433],
#        [ 4.5316483 ],
#        [ 2.47375874],
#        [ 1.58128655],
#        [ 1.93106071],
#        [ 5.22093087],
#        [ 3.80758515],
#        [ 3.24771876],
#        [-0.12176919],
#        [ 0.61691154],
# ...

# %%
plt.plot(x,y, "b.")
plt.xlabel("$x_1$", fontsize = 13)
plt.ylabel("$y$", rotation = 0, fontsize = 13)
plt.axis([0,2,0,15])
plt.show()

# %%
#here it shows different (which is not exactly pure linear data)

# %%
ones = np.ones((100,1))
x_b = np.c_[ones,x]
x_b
# Out:
# array([[1.        , 1.18878939],
#        [1.        , 1.96099738],
#        [1.        , 0.66839198],
#        [1.        , 1.21386085],
#        [1.        , 1.72836568],
#        [1.        , 0.06329984],
#        [1.        , 1.1125735 ],
#        [1.        , 1.39634695],
#        [1.        , 0.82668894],
#        [1.        , 1.38167996],
#        [1.        , 1.31191636],
#        [1.        , 0.24279107],
#        [1.        , 1.62432911],
#        [1.        , 1.5361099 ],
#        [1.        , 0.38859573],
#        [1.        , 0.99767938],
#        [1.        , 0.25471912],
#        [1.        , 0.03094778],
#        [1.        , 0.02556884],
#        [1.        , 1.78837636],
#        [1.        , 1.55711577],
#        [1.        , 1.79805824],
#        [1.        , 0.69613028],
#        [1.        , 0.63148179],
#        [1.        , 0.87975827],
#        [1.        , 0.92407284],
#        [1.        , 0.22496953],
#        [1.        , 1.95333624],
# ...

# %%
theta_best = np.linalg.inv(x_b.T.dot(x_b)).dot(x_b.T).dot(y)
theta_best
# Out:
# array([[0.19550414],
#        [2.84333862]])

# %%
x_data = x[0]
x_data
# Out:
# array([1.18878939])

# %%
x_data = np.c_[np.ones((1, 1)), x_data]
x_data
# Out:
# array([[1.        , 1.18878939]])

# %%
y_pred = x_data.dot(theta_
