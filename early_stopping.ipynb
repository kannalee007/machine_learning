# %%
import numpy as np
from sklearn.linear_model import SGDRegressor #inbuilt

# %%
m = 100
X = 4 * np.random.rand(m, 1)
y = 3.46 * X + 3 + np.random.randn(m, 1)

# %%
early = SGDRegressor(max_iter = 1000, tol = 0.23, penalty = None, learning_rate = 'constant', eta0= 0.02, random_state = 32)

# %%
early.fit()
